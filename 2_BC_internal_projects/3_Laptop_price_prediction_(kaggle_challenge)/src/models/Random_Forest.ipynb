# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import numpy as np
import urllib.request
from PIL import Image

import ML_tool_box_basic_plot as tbb

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data

# %%
### Para que funcione necesitas bajarte los archivos de datos de Kaggle 
df = pd.read_csv("data/portatiles_train.csv", index_col = 0)
df.index.name = None

# %% [markdown]
# ## Data exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Company                  912 non-null    object
#  1   TypeName                 912 non-null    object
#  2   Inches                   912 non-null    float64
#  3   ScreenResolution         912 non-null    object
#  4   Cpu                      912 non-null    object
#  5   Ram                      912 non-null    object
#  6   Memory                   912 non-null    object
#  7   Gpu                      912 non-null    object
#  8   OpSys                    912 non-null    object
#  9   Weight                   912 non-null    object
#  10  Price_in_euros           912 non-null    float64
#  11  ram_gb                   912 non-null    int64
#  12  weight_kg                912 non-null    float64
#  13  cluster_Company          912 non-null    int64
#  14  median_price_company     912 non-null    float64
#  15  median_price_typename    912 non-null    float64
#  16  cluster_Inches           912 non-null    int64
#  17  median_price_inches      912 non-null    float64
#  18  Resolution_Type          912 non-null    object
#  19  Resolution_Pixels        912 non-null    int64
#  20  Touchscreen              912 non-null    int64
#  21  cluster_Resolution_Type  912 non-null    int64
#  22  median_price_screen      912 non-null    float64
#  23  CPU_Manufacturer         912 non-null    object
#  24  CPU_Model                912 non-null    object
#  25  CPU_Frequency            912 non-null    float64
#  26  CPU_Model_Class          912 non-null    object
#  27  cluster_Cpu_Class        912 non-null    int64
#  28  median_price_cpu_model   912 non-null    float64
#  29  SSD_(GB)                 912 non-null    int64
#  30  HDD_(GB)                 912 non-null    int64
#  31  Flash_Storage_(GB)       912 non-null    int64
#  32  Hybrid_(GB)              912 non-null    int64
#  33  OtherTypeStorage_(GB)    912 non-null    int64
#  34  Gpu_Company              912 non-null    object
#  35  Gpu_Family               912 non-null    object
#  36  Gpu_Model                912 non-null    object
#  37  Integrada_Externa        912 non-null    int64
#  38  cluster_Gpu              912 non-null    int64
#  39  median_price_Gpu         912 non-null    float64
#  40  cluster_OS               912 non-null    int64
#  41  median_price_OS          912 non-null    float64
# dtypes: float64(11), int64(15), object(16)
# memory usage: 306.4+ KB

# %% [markdown]
# ## Data processing

# %%
# Outlier

filtro = df["Price_in_euros"] > 6000
df.loc[filtro]
# Out:
#     Company TypeName  Inches                     ScreenResolution  \
# 200   Razer   Gaming    17.3  4K Ultra HD / Touchscreen 3840x2160
#
#                              Cpu   Ram   Memory                      Gpu  \
# 200  Intel Core i7 7820HK 2.9GHz  32GB  1TB SSD  Nvidia GeForce GTX 1080
#
#           OpSys  Weight  Price_in_euros  ram_gb  weight_kg  cluster_Company  \
# 200  Windows 10  3.49kg          6099.0      32       3.49                1
#
#      median_price_company  median_price_typename  cluster_Inches  \
# 200                2749.0                 1479.0               5
#
#      median_price_inches Resolution_Type  Resolution_Pixels  Touchscreen  \
# 200               1409.0       3840x2160            8294400            1
#
#      cluster_Resolution_Type  median_price_screen CPU_Manufacturer  \
# 200                        5              2020.71            Intel
#
#           CPU_Model  CPU_Frequency CPU_Model_Class  cluster_Cpu_Class  \
# 200  Core i7 7820HK            2.9          Core i                  2
#
#      median_price_cpu_model  SSD_(GB)  HDD_(GB)  Flash_Storage_(GB)  \
# 200                  1180.7      1024         0                   0
#
#      Hybrid_(GB)  OtherTypeStorage_(GB) Gpu_Company   Gpu_Family Gpu_Model  \
# 200            0                      0      Nvidia  GeForce GTX      1080
#
#      Integrada_Externa  cluster_Gpu  median_price_Gpu  cluster_OS  \
# 200                  1            5            1420.0           4
#
#      median_price_OS
# 200           1043.0

# %%
df.drop(index=200, inplace=True)
filtro = df["Price_in_euros"] > 6000
df.loc[filtro]
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_in_euros, ram_gb, weight_kg, cluster_Company, median_price_company, median_price_typename, cluster_Inches, median_price_inches, Resolution_Type, Resolution_Pixels, Touchscreen, cluster_Resolution_Type, median_price_screen, CPU_Manufacturer, CPU_Model, CPU_Frequency, CPU_Model_Class, cluster_Cpu_Class, median_price_cpu_model, SSD_(GB), HDD_(GB), Flash_Storage_(GB), Hybrid_(GB), OtherTypeStorage_(GB), Gpu_Company, Gpu_Family, Gpu_Model, Integrada_Externa, cluster_Gpu, median_price_Gpu, cluster_OS, median_price_OS]
# Index: []

# %%
target = "Price_in_euros"

# %% [markdown]
# Cambiamos el valor de varias variables a category para poder usarlas con mejores garantias en algunos modelos.

# %%
columnas_type_category = ['cluster_Company', 'cluster_Inches', 'cluster_Resolution_Type', 'cluster_Cpu_Class', 'cluster_Gpu', 'cluster_OS']
df[columnas_type_category] = df[columnas_type_category].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 911 entries, 755 to 229
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Company                  911 non-null    object
#  1   TypeName                 911 non-null    object
#  2   Inches                   911 non-null    float64
#  3   ScreenResolution         911 non-null    object
#  4   Cpu                      911 non-null    object
#  5   Ram                      911 non-null    object
#  6   Memory                   911 non-null    object
#  7   Gpu                      911 non-null    object
#  8   OpSys                    911 non-null    object
#  9   Weight                   911 non-null    object
#  10  Price_in_euros           911 non-null    float64
#  11  ram_gb                   911 non-null    int64
#  12  weight_kg                911 non-null    float64
#  13  cluster_Company          911 non-null    category
#  14  median_price_company     911 non-null    float64
#  15  median_price_typename    911 non-null    float64
#  16  cluster_Inches           911 non-null    category
#  17  median_price_inches      911 non-null    float64
#  18  Resolution_Type          911 non-null    object
#  19  Resolution_Pixels        911 non-null    int64
#  20  Touchscreen              911 non-null    int64
#  21  cluster_Resolution_Type  911 non-null    category
#  22  median_price_screen      911 non-null    float64
#  23  CPU_Manufacturer         911 non-null    object
#  24  CPU_Model                911 non-null    object
#  25  CPU_Frequency            911 non-null    float64
#  26  CPU_Model_Class          911 non-null    object
#  27  cluster_Cpu_Class        911 non-null    category
#  28  median_price_cpu_model   911 non-null    float64
#  29  SSD_(GB)                 911 non-null    int64
#  30  HDD_(GB)                 911 non-null    int64
#  31  Flash_Storage_(GB)       911 non-null    int64
#  32  Hybrid_(GB)              911 non-null    int64
#  33  OtherTypeStorage_(GB)    911 non-null    int64
#  34  Gpu_Company              911 non-null    object
#  35  Gpu_Family               911 non-null    object
#  36  Gpu_Model                911 non-null    object
#  37  Integrada_Externa        911 non-null    int64
#  38  cluster_Gpu              911 non-null    category
#  39  median_price_Gpu         911 non-null    float64
#  40  cluster_OS               911 non-null    category
#  41  median_price_OS          911 non-null    float64
# dtypes: category(6), float64(11), int64(9), object(16)
# memory usage: 270.2+ KB

# %%
df.head()
# Out:
#     Company   TypeName  Inches   ScreenResolution  \
# 755      HP   Notebook    15.6  Full HD 1920x1080
# 618    Dell     Gaming    15.6  Full HD 1920x1080
# 909      HP   Notebook    15.6  Full HD 1920x1080
# 2     Apple  Ultrabook    13.3           1440x900
# 286    Dell   Notebook    15.6  Full HD 1920x1080
#
#                              Cpu   Ram               Memory  \
# 755     Intel Core i3 6006U 2GHz   8GB            256GB SSD
# 618  Intel Core i7 6700HQ 2.6GHz  16GB              1TB HDD
# 909   Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
# 2           Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 286   Intel Core i3 6006U 2.0GHz   4GB              1TB HDD
#
#                                 Gpu       OpSys  Weight  Price_in_euros  \
# 755           Intel HD Graphics 520  Windows 10  1.86kg          539.00
# 618  Nvidia GeForce GTX 960<U+039C>  Windows 10  2.59kg          879.01
# 909            Nvidia GeForce 930MX  Windows 10  2.04kg          900.00
# 2            Intel HD Graphics 6000       macOS  1.34kg          898.94
# 286              AMD Radeon R5 M430       Linux  2.25kg          428.00
#
#      ram_gb  weight_kg cluster_Company  median_price_company  \
# 755       8       1.86               0               964.925
# 618      16       2.59               0               964.925
# 909       8       2.04               0               964.925
# 2         8       1.34               4              1678.800
# 286       4       2.25               0               964.925
#
#      median_price_typename cluster_Inches  median_price_inches  \
# 755                  685.0              1           750.000000
# 618                 1479.0              1           750.000000
# 909                  685.0              1           750.000000
# 2                   1499.0              4          1412.331667
# 286                  685.0              1           750.000000
#
#     Resolution_Type  Resolution_Pixels  Touchscreen cluster_Resolution_Type  \
# 755       1920x1080            2073600            0                       3
# 618       1920x1080            2073600            0                       3
# 909       1920x1080            2073600            0                       3
# 2          1440x900            1296000            0                       2
# 286       1920x1080            2073600            0                       3
#
#      median_price_screen CPU_Manufacturer       CPU_Model  CPU_Frequency  \
# 755              1103.00            Intel   Core i3 6006U            2.0
# 618              1103.00            Intel  Core i7 6700HQ            2.6
# 909              1103.00            Intel   Core i7 7500U            2.7
# 2                1310.55            Intel         Core i5            1.8
# 286              1103.00            Intel   Core i3 6006U            2.0
#
#     CPU_Model_Class cluster_Cpu_Class  median_price_cpu_model  SSD_(GB)  \
# 755          Core i                 2                  1180.7       256
# 618          Core i                 2                  1180.7         0
# 909          Core i                 2                  1180.7         0
# 2            Core i                 2                  1180.7         0
# 286          Core i                 2                  1180.7         0
#
#      HDD_(GB)  Flash_Storage_(GB)  Hybrid_(GB)  OtherTypeStorage_(GB)  \
# 755         0                   0            0                      0
# 618      1024                   0            0                      0
# 909      1024                   0            0                      0
# 2           0                 128            0                      0
# 286      1024                   0            0                      0
#
#     Gpu_Company   Gpu_Family    Gpu_Model  Integrada_Externa cluster_Gpu  \
# 755       Intel  HD Graphics          520                  0           3
# 618      Nvidia  GeForce GTX  960<U+039C>                  1           5
# 909      Nvidia      GeForce        930MX                  1           3
# 2         Intel  HD Graphics         6000                  0           3
# 286         AMD  Radeon R5 M         M430                  1           1
#
#      median_price_Gpu cluster_OS  median_price_OS
# 755       1002.578333          4          1043.00
# 618       1420.000000          4          1043.00
# 909       1002.578333          4          1043.00
# 2         1002.578333          3          1518.55
# 286        505.140625          0           471.75

# %%
features_all_RF = df.iloc[:, [11,14,15,17,20,22,28,29,30,31,32,37,39,41]]
columnas_no_object = features_all_RF.select_dtypes(exclude=['object'])
features_num = list(columnas_no_object.columns)
features_num
# Out:
# ['ram_gb',
#  'median_price_company',
#  'median_price_typename',
#  'median_price_inches',
#  'Touchscreen',
#  'median_price_screen',
#  'median_price_cpu_model',
#  'SSD_(GB)',
#  'HDD_(GB)',
#  'Flash_Storage_(GB)',
#  'Hybrid_(GB)',
#  'Integrada_Externa',
#  'median_price_Gpu',
#  'median_price_OS']

# %%
tbb.REGRE_FN_BI_FeaNum_hist_scatter_plot_with_regression(df, target, columnas=features_num, umbral_categorias_feature=2)
# Out:
# ## Test de Person para correlación entre variables y su significancia ##
#                    Feature      Corr Direction        p-value
# 1                   ram_gb  0.731569         +  2.154624e-153
# 10                SSD_(GB)  0.660719         +  2.320678e-115
# 4    median_price_typename  0.636512         +  1.222083e-104
# 7      median_price_screen  0.604869         +   5.382647e-92
# 14        median_price_Gpu  0.531594         +   1.384579e-67
# 9   median_price_cpu_model  0.494037         +   3.137037e-57
# 5      median_price_inches  0.481828         +   3.926738e-54
# 6        Resolution_Pixels  0.476587         +   7.687728e-53
# 8            CPU_Frequency  0.430590         +   2.035942e-42
# 3     median_price_company  0.356599         +   1.050097e-28
# 15         median_price_OS  0.339384         +   5.413060e-26
# 2                weight_kg  0.185486         +   1.702337e-08
# 11                HDD_(GB)  0.071828         -   3.017445e-02
# 0                   Inches  0.060031         +   7.013482e-02
# 12      Flash_Storage_(GB)  0.042496         -   2.000347e-01
# 13             Hybrid_(GB)  0.037809         -   2.542731e-01
#
# ## Test de Fuerza entre variables y su significancia ##
# Las siguientes columnas se han quitado por NO ser numéricas: ['Company', 'TypeName', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'cluster_Company', 'cluster_Inches', 'Resolution_Type', 'cluster_Resolution_Type', 'CPU_Manufacturer', 'CPU_Model', 'CPU_Model_Class', 'cluster_Cpu_Class', 'Gpu_Company', 'Gpu_Family', 'Gpu_Model', 'cluster_Gpu', 'cluster_OS']
# Las siguientes columnas númericas se han quitado por tener menos de 3 valores únicos y considerarse categóricas: ['OtherTypeStorage_(GB)']
#
#                    Feature      F-value        p-value
# 1                   ram_gb  1046.649645  2.154624e-153
# 11                SSD_(GB)   704.275891  2.320678e-115
# 4    median_price_typename   619.109579  1.222083e-104
# 8      median_price_screen   524.453451   5.382647e-92
# 16        median_price_Gpu   358.062598   1.384579e-67
# 10  median_price_cpu_model   293.496400   3.137037e-57
# 5      median_price_inches   274.837983   3.926738e-54
# 6        Resolution_Pixels   267.143880   7.687728e-53
# 9            CPU_Frequency   206.895679   2.035942e-42
# 3     median_price_company   132.431729   1.050097e-28
# 17         median_price_OS   118.329580   5.413060e-26
# 15       Integrada_Externa    67.801946   6.249884e-16
# 7              Touchscreen    40.006147   3.966377e-10
# 2                weight_kg    32.388624   1.702337e-08
# 12                HDD_(GB)     4.714092   3.017445e-02
# 0                   Inches     3.287597   7.013482e-02
# 13      Flash_Storage_(GB)     1.644510   2.000347e-01
# 14             Hybrid_(GB)     1.301318   2.542731e-01
# ['ram_gb',
#  'median_price_company',
#  'median_price_typename',
#  'median_price_inches',
#  'Touchscreen',
#  'median_price_screen',
#  'median_price_cpu_model',
#  'SSD_(GB)',
#  'HDD_(GB)',
#  'Flash_Storage_(GB)',
#  'Hybrid_(GB)',
#  'Integrada_Externa',
#  'median_price_Gpu',
#  'median_price_OS']

# %%
features_all_RF_def = df.iloc[:, [11,14,15,17,22,28,29,37,39,41]]
columnas_no_object = features_all_RF_def.select_dtypes(exclude=['object'])
features_num_def = list(columnas_no_object.columns)
features_num_def
# Out:
# ['ram_gb',
#  'median_price_company',
#  'median_price_typename',
#  'median_price_inches',
#  'median_price_screen',
#  'median_price_cpu_model',
#  'SSD_(GB)',
#  'Integrada_Externa',
#  'median_price_Gpu',
#  'median_price_OS']

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Modelado

# %% [markdown]
# ### 1. Definir X e y

# %%
X = df[features_num_def].copy()
y = df['Price_in_euros'].copy()
X.shape
# Out:
# (911, 10)

# %%
X
# Out:
#       ram_gb  median_price_company  median_price_typename  \
# 755        8               964.925                685.000
# 618       16               964.925               1479.000
# 909        8               964.925                685.000
# 2          8              1678.800               1499.000
# 286        4               964.925                685.000
# ...      ...                   ...                    ...
# 28         8               964.925                685.000
# 1160       8               964.925               1378.495
# 78         8               964.925                685.000
# 23         4               964.925                685.000
# 229       16               964.925               1479.000
#
#       median_price_inches  median_price_screen  median_price_cpu_model  \
# 755            750.000000              1103.00                1180.700
# 618            750.000000              1103.00                1180.700
# 909            750.000000              1103.00                1180.700
# 2             1412.331667              1310.55                1180.700
# 286            750.000000              1103.00                1180.700
# ...                   ...                  ...                     ...
# 28             750.000000              1103.00                1180.700
# 1160          1412.331667              1103.00                1180.700
# 78             750.000000              1103.00                1180.700
# 23             750.000000               459.00                 350.616
# 229           1409.000000              1103.00                1180.700
#
#       SSD_(GB)  Integrada_Externa  median_price_Gpu  median_price_OS
# 755        256                  0       1002.578333          1043.00
# 618          0                  1       1420.000000          1043.00
# 909          0                  1       1002.578333          1043.00
# 2            0                  0       1002.578333          1518.55
# 286          0                  1        505.140625           471.75
# ...        ...                ...               ...              ...
# 28         256                  0        505.140625          1043.00
# 1160       256                  0       1002.578333          1043.00
# 78           0                  0       1002.578333           471.75
# 23           0                  0        505.140625           471.75
# 229        256                  1       1420.000000          1043.00
#
# [911 rows x 10 columns]

# %%
y.shape
# Out:
# (911,)

# %% [markdown]
# ### 2. Dividir X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
X_train.head(5)
# Out:
#       ram_gb  median_price_company  median_price_typename  \
# 1118       8            964.925000                 1984.0
# 563        4            247.448333                  685.0
# 275        8           1678.800000                 1499.0
# 1211       8           1678.800000                 1499.0
# 131       16            964.925000                  685.0
#
#       median_price_inches  median_price_screen  median_price_cpu_model  \
# 1118          1409.000000             1103.000                1180.700
# 563           1412.331667             1103.000                 350.616
# 275           1412.331667             2032.333                1180.700
# 1211          1347.350000             1310.550                1180.700
# 131           1409.000000             1103.000                1180.700
#
#       SSD_(GB)  Integrada_Externa  median_price_Gpu  median_price_OS
# 1118         0                  1       1420.000000          1417.50
# 563          0                  0        505.140625          1043.00
# 275        512                  0       1600.825000          1518.55
# 1211         0                  0       1002.578333          1131.00
# 131        256                  0        505.140625          1043.00

# %%
y_train
# Out:
# 1118    2899.00
# 563      255.00
# 275     1958.90
# 1211    1163.00
# 131     1396.00
#          ...
# 95      1195.00
# 647     2399.00
# 187      793.00
# 775      470.34
# 762     1096.00
# Name: Price_in_euros, Length: 728, dtype: float64

# %% [markdown]
# ### 3. Baseline de modelos

# %%
model = RandomForestRegressor(max_depth = 5, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, random_state=42)

# %% [markdown]
# ### 4. Sacar métricas, valorar los modelos
#
# Recuerda que en la competición se va a evaluar con la métrica de RMSE.

# %%
predict = model.predict(X_test)

mse = mean_squared_error(y_test, predict)
rmse = np.sqrt(mse)
rmse
# Out:
# 302.3112453863824

# %%
from sklearn.model_selection import cross_val_score


# Definir el modelo
model_cross = RandomForestRegressor(max_depth=5, random_state=42)

# Realizar el Cross-Validation con 5 folds
scores = cross_val_score(model_cross, X_train, y_train, cv=5, scoring='neg_mean_squared_error')

# Calcular el RMSE promedio y mostrar el resultado
rmse_scores = np.sqrt(-scores)
print(f"RMSE por pliegue: {rmse_scores}")
print(f"RMSE promedio: {rmse_scores.mean()}")
# Out:
# RMSE por pliegue: [301.22454172 337.26997698 293.73169999 362.79258566 329.22648233]
# RMSE promedio: 324.84905733453206

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir ``test.csv``

# %% [markdown]
# **RECUERDA: APLICAR LAS TRANSFORMACIONES QUE HAYAS REALIZADO EN `train.csv` a `test.csv`.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ### 1. Carga los datos de `test.csv` para predecir.

# %%
X_pred = pd.read_csv("data/portatiles_test.csv", index_col = 0)
X_pred.index.name = None
X_pred.head()
# Out:
#      Company            TypeName  Inches  \
# 209   Lenovo              Gaming    15.6
# 1281    Acer            Notebook    15.6
# 1168  Lenovo            Notebook    15.6
# 1231    Dell  2 in 1 Convertible    15.6
# 1020      HP            Notebook    14.0
#
#                                ScreenResolution  \
# 209                           Full HD 1920x1080
# 1281                                   1366x768
# 1168                                   1366x768
# 1231  IPS Panel Full HD / Touchscreen 1920x1080
# 1020                          Full HD 1920x1080
#
#                                        Cpu   Ram     Memory  \
# 209            Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD
# 1281  Intel Celeron Dual Core N3060 1.6GHz   4GB  500GB HDD
# 1168            Intel Core i3 6006U 2.0GHz   4GB    1TB HDD
# 1231            Intel Core i5 7200U 2.5GHz   8GB  256GB SSD
# 1020            Intel Core i5 7200U 2.5GHz   4GB  256GB SSD
#
#                           Gpu       OpSys   Weight  ram_gb  weight_kg  \
# 209   Nvidia GeForce GTX 1060       No OS    2.4kg      16      2.400
# 1281    Intel HD Graphics 400       Linux    2.4kg       4      2.400
# 1168    Intel HD Graphics 520       No OS    1.9kg       4      1.900
# 1231    Intel HD Graphics 620  Windows 10  2.191kg       8      2.191
# 1020    Intel HD Graphics 620  Windows 10   1.95kg       4      1.950
#
#       cluster_Company  median_price_company  median_price_typename  \
# 209                 0               964.925               1479.000
# 1281                6               645.250                685.000
# 1168                0               964.925                685.000
# 1231                0               964.925               1378.495
# 1020                0               964.925                685.000
#
#       cluster_Inches  median_price_inches Resolution_Type  Resolution_Pixels  \
# 209              1.0                750.0       1920x1080            2073600
# 1281             1.0                750.0        1366x768            1049088
# 1168             1.0                750.0        1366x768            1049088
# 1231             1.0                750.0       1920x1080            2073600
# 1020             2.0               1097.5       1920x1080            2073600
#
#       Touchscreen  cluster_Resolution_Type  median_price_screen  \
# 209             0                      3.0               1103.0
# 1281            0                      4.0                459.0
# 1168            0                      4.0                459.0
# 1231            1                      3.0               1103.0
# 1020            0                      3.0               1103.0
#
#      CPU_Manufacturer                CPU_Model  CPU_Frequency CPU_Model_Class  \
# 209             Intel           Core i7 7700HQ            2.8          Core i
# 1281            Intel  Celeron Dual Core N3060            1.6         Celeron
# 1168            Intel            Core i3 6006U            2.0          Core i
# 1231            Intel            Core i5 7200U            2.5          Core i
# 1020            Intel            Core i5 7200U            2.5          Core i
#
#       cluster_Cpu_Class  median_price_cpu_model  SSD_(GB)  HDD_(GB)  \
# 209                   2                1180.700       256         0
# 1281                  0                 350.616         0      1024
# 1168                  2                1180.700         0      1024
# 1231                  2                1180.700         0         0
# 1020                  2                1180.700         0      1024
#
#       Flash_Storage_(GB)  Hybrid_(GB)  OtherTypeStorage_(GB) Gpu_Company  \
# 209                    0            0                      0      Nvidia
# 1281                   0            0                      0       Intel
# 1168                   0            0                      0       Intel
# 1231                 128            0                      0       Intel
# 1020                   0            0                      0       Intel
#
#        Gpu_Family Gpu_Model  Integrada_Externa  cluster_Gpu  median_price_Gpu  \
# 209   GeForce GTX      1060                1.0          5.0       1420.000000
# 1281  HD Graphics       400                0.0          3.0       1002.578333
# 1168  HD Graphics       520                0.0          3.0       1002.578333
# 1231  HD Graphics       620                0.0          3.0       1002.578333
# 1020  HD Graphics       620                0.0          3.0       1002.578333
#
#       cluster_OS  median_price_OS
# 209            0           471.75
# 1281           0           471.75
# 1168           0           471.75
# 1231           4          1043.00
# 1020           4          1043.00

# %%
X_pred.shape
# Out:
# (391, 41)

# %%
X_pred = X_pred[features_num_def]

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ram_gb                  391 non-null    int64
#  1   median_price_company    391 non-null    float64
#  2   median_price_typename   391 non-null    float64
#  3   median_price_inches     390 non-null    float64
#  4   median_price_screen     390 non-null    float64
#  5   median_price_cpu_model  391 non-null    float64
#  6   SSD_(GB)                391 non-null    int64
#  7   Integrada_Externa       390 non-null    float64
#  8   median_price_Gpu        388 non-null    float64
#  9   median_price_OS         391 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 33.6 KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 728 entries, 1118 to 762
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ram_gb                  728 non-null    int64
#  1   median_price_company    728 non-null    float64
#  2   median_price_typename   728 non-null    float64
#  3   median_price_inches     728 non-null    float64
#  4   median_price_screen     728 non-null    float64
#  5   median_price_cpu_model  728 non-null    float64
#  6   SSD_(GB)                728 non-null    int64
#  7   Integrada_Externa       728 non-null    int64
#  8   median_price_Gpu        728 non-null    float64
#  9   median_price_OS         728 non-null    float64
# dtypes: float64(7), int64(3)
# memory usage: 62.6 KB

# %%
predictions_submit = model.predict(X_pred)
predictions_submit
# Out:
# array([1658.43105647,  326.2045339 ,  531.5846519 , 1117.40611358,
#         736.35652058,  502.76785715,  767.81187336,  875.95518828,
#        1292.33687473,  532.53561236, 2116.66095084, 1326.59347752,
#         727.79614735, 1685.92738527,  841.2548954 ,  657.46467023,
#        1934.58243987, 1428.53677433, 1340.62811738,  681.44152637,
#        1511.62183987,  367.93490527,  860.64179625, 1323.13682282,
#         673.83120235,  838.05361872,  695.80976023, 1064.4268846 ,
#        2224.49382727, 1066.96325192, 2120.20452643,  642.18218082,
#         668.99887748, 3181.00303164, 1677.37182216, 2087.31044452,
#         662.59130949, 1653.84576381,  838.05361872, 1249.87319599,
#         841.2548954 , 1366.3532045 ,  538.99976477, 1076.75423892,
#        1231.27567438, 1183.28914414,  961.84241757,  691.3621156 ,
#        1037.0924238 ,  514.13468909, 1594.71726404,  837.12845556,
#        1284.61302574,  531.5846519 , 1849.91843919, 1410.7431623 ,
#         704.51851493, 1066.96325192, 1218.92432114,  568.30018513,
#        2254.79624162, 1794.37915094,  543.62823645, 2037.57770914,
#         970.81381534, 1366.31976505,  760.31603862, 1324.35841612,
#        2069.84500263, 2034.99669753,  644.14445001,  796.34661208,
#        1076.97723278, 1230.36289747, 1041.27687547, 1185.40540118,
#        1321.3112187 , 1366.3532045 , 1511.62183987, 1326.59347752,
#         877.56726636, 1261.10210481, 2201.6593972 , 1330.01669276,
#        1414.84051976, 1627.45670079,  326.26821307, 1103.61843281,
#        1041.9997936 ,  773.40277877,  504.01375382, 1664.61942199,
#        1249.87319599, 3192.11195613, 2113.23517422, 1606.08323626,
#         795.31045976,  749.59089727, 1041.27687547, 1039.49325668,
#        2113.23517422,  684.98128803, 1790.89535743, 1249.87319599,
#         326.2045339 , 1627.45670079, 2083.54941496,  830.64443433,
#         426.91787123, 1213.73328686, 1326.59347752,  835.21312333,
#         756.13078599,  939.39017159,  838.05361872,  696.43864022,
#         557.00909152, 1041.27687547, 2137.99638011, 1366.3532045 ,
#         837.12845556,  649.95064899,  877.56726636,  898.54284988,
#        1964.03672659,  531.5846519 ,  898.59969864, 1041.27687547,
#         656.53950707,  872.27977576, 1954.46513223, 1433.85100988,
#        1470.44921987, 1501.59174301,  644.14445001, 2595.03231003,
#        1289.43862574, 1415.4674298 , 1369.77641975,  681.44152637,
#        1388.69549341,  939.39017159, 1370.63081106,  850.59162598,
#        1418.52017537, 1366.3532045 , 1383.61970577, 1206.72072766,
#        1470.44921987, 1033.51395478, 1033.51395478,  838.05361872,
#         485.17838187, 1342.06827498, 1041.27687547,  838.05361872,
#        1047.25617737, 1185.40540118,  824.61556202,  473.52509094,
#         681.44152637, 1784.80332851, 1213.73328686,  696.43864022,
#        1041.27687547,  877.56726636, 2133.42628518,  473.22448683,
#         944.37227716, 1227.45931132, 1353.13111559,  657.46467023,
#         473.52509094,  665.2235672 , 1511.62183987,  656.53950707,
#         838.05361872,  595.79134408, 1076.75423892,  991.59925628,
#         600.13288326, 2984.96375374, 1066.96325192,  865.29890672,
#        1370.63081106, 2028.95028686,  326.26821307,  794.74019996,
#        1366.3532045 , 1041.27687547,  704.51851493, 1625.1945604 ,
#         486.55338187,  785.35856342,  684.98128803,  495.51131675,
#        1369.77641975,  838.05361872, 1041.27687547,  486.79242849,
#        1059.20033123, 2113.23517422,  941.22428777,  765.62689836,
#         645.18155604,  327.0263157 , 2113.23517422,  324.77654372,
#        1326.59347752,  606.51371084, 1292.33687473,  776.72379038,
#         684.98128803,  838.05361872,  752.97031142, 1366.3532045 ,
#        1033.51395478, 1035.30880502,  841.2548954 ,  668.99887748,
#         613.30657104, 1370.63081106, 1242.61672081,  742.9922382 ,
#         749.88183132, 1199.29364327,  465.10707303, 1213.73328686,
#         686.95795469, 2120.20452643,  501.6895356 ,  613.41408809,
#        1185.40540118, 1318.88897734,  457.81452097, 1185.40540118,
#        3181.00303164, 1428.53677433, 1262.29056574, 1041.27687547,
#        1354.11177341,  600.13288326, 1230.56656369, 1162.84425696,
#        1033.51395478, 2113.23517422, 1146.07207274,  970.81381534,
#         839.09072475, 2120.20452643, 1431.77551332,  657.46467023,
#        2119.44552632, 1041.27687547, 2097.16080602, 2134.08624911,
#         736.35652058,  369.85740176, 1076.75423892, 1185.40540118,
#         684.98128803,  595.79134408, 1070.99793087,  644.14445001,
#        2113.23517422, 2110.0471517 , 1353.13111559,  457.81452097,
#        1342.44397944, 1811.27398354,  514.13468909,  619.68739862,
#        1103.61843281, 1225.66502487, 1643.81566694, 1062.77880026,
#         696.43864022,  899.88504674,  877.56726636,  512.39551008,
#         700.52519555, 1185.40540118, 1430.12920063,  691.3621156 ,
#         519.26827481, 1333.88741366, 1249.87319599, 1802.80788952,
#        3181.00303164,  567.6038513 , 1072.94255383, 1370.63081106,
#        1354.11177341, 1066.96325192, 1210.91376321, 1224.50977835,
#        1326.59347752, 1230.36289747, 2709.68322005, 1243.81641065,
#        1369.94433243,  531.5846519 ,  491.83868035,  684.98128803,
#         759.29106002, 1333.33418125, 1947.36665159,  754.98107521,
#        2018.42638932, 1375.72109   ,  600.13288326,  763.39210691,
#         402.3748343 ,  694.92500359,  944.37227716,  853.35316738,
#        1912.28788697, 1062.33893649, 1218.92432114,  856.72412012,
#        1366.3532045 , 1208.12312571, 1197.17738622, 1041.27687547,
#        1070.99793087, 2018.42638932, 1981.74754523,  521.11828977,
#         593.85957273, 1750.86137542,  324.77654372,  838.05361872,
#        1333.33418125,  736.35652058,  496.75676427, 1033.51395478,
#         644.14445001,  611.02671523, 1324.47722047, 1492.01389321,
#         502.76785715,  657.46467023, 2362.10850424,  898.54284988,
#        1230.36289747,  838.05361872,  327.0263157 , 1213.73328686,
#         848.81808369,  657.46467023, 1047.25617737, 1055.01587957,
#         687.0347242 ,  696.43864022,  787.80544475,  326.2045339 ,
#        1230.36289747,  759.40523783, 1068.68154355, 2136.46825825,
#         644.14445001,  759.40523783,  993.10656404, 1284.61302574,
#        1452.58255687, 1675.85615537, 1230.36289747, 3192.11195613,
#         731.86563151, 2017.1260488 , 2029.38255377, 1476.22503625,
#         646.95127377, 1353.28385997,  944.37227716, 1786.28655236,
#         700.52519555, 1066.96325192,  695.96583991,  696.65012941,
#         327.0263157 , 1059.20033123,  895.03740677,  327.0263157 ,
#        1230.36289747, 1039.49325668, 2094.27979673,  794.60905072,
#        1900.64430106,  731.86563151, 1230.36289747])

# %% [markdown]
# **¡OJO! ¿Por qué me da error?**

# %% [markdown]
# IMPORTANTE:
#
# - SI EL ARRAY CON EL QUE HICISTEIS `.fit()` ERA DE 4 COLUMNAS, PARA `.predict()` DEBEN SER LAS MISMAS
# - SI AL ARRAY CON EL QUE HICISTEIS `.fit()` LO NORMALIZASTEIS, PARA `.predict()` DEBÉIS NORMALIZARLO
# - TODO IGUAL SALVO **BORRAR FILAS**, EL NÚMERO DE ROWS SE DEBE MANTENER EN ESTE SET, PUES LA PREDICCIÓN DEBE TENER **391 FILAS**, SI O SI

# %% [markdown]
# **Entonces, si al cargar los datos de ``train.csv`` usaste `index_col=0`, ¿tendré que hacer lo también para el `test.csv`?**

# %%
# ¿Qué opináis?
# ¿Sí, no?

# %% [markdown]
# ![wow.jpeg](attachment:wow.jpeg)

# %% [markdown]
# ### 3. **¿Qué es lo que subirás a Kaggle?**

# %% [markdown]
# **Para subir a Kaggle la predicción esta tendrá que tener una forma específica.**
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
sample = pd.read_csv("data/sample_submission.csv")

# %%
sample.head()
# Out:
#    laptop_ID  Price_in_euros
# 0        209          1949.1
# 1       1281           805.0
# 2       1168          1101.0
# 3       1231          1293.8
# 4       1020          1832.6

# %%
sample.shape
# Out:
# (391, 2)

# %% [markdown]
# ### 4. Mete tus predicciones en un dataframe llamado ``submission``.

# %%
submission = pd.DataFrame({"laptop_ID": X_pred.index, "Price_in_euros": predictions_submit})

# %%
submission.head()
# Out:
#    laptop_ID  Price_in_euros
# 0        209     1658.431056
# 1       1281      326.204534
# 2       1168      531.584652
# 3       1231     1117.406114
# 4       1020      736.356521

# %%
submission.shape
# Out:
# (391, 2)

# %% [markdown]
# # Cambiar nombre de la ruta!!!

# %%
submission.to_csv("./data/submission_RandomForest.csv", index=False)

# %% [markdown]
# ### 5. Pásale el CHEQUEADOR para comprobar que efectivamente está listo para subir a Kaggle.

# %%
def chequeador(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.laptop_ID.all() == sample.laptop_ID.all():
                print("You're ready to submit!")
                submission.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://www.mihaileric.com/static/evaluation-meme-e0a350f278a36346e6d46b139b1d0da0-ed51e.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto de Iván y Manuel: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `laptops_test.csv`. Lloramos.")

# %%
chequeador(submission)
# Out:
# You're ready to submit!
